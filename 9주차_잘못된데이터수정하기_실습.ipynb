# %% [markdown]
# <a href="https://colab.research.google.com/github/hiuk21/new-project/blob/main/9%EC%A3%BC%EC%B0%A8_%EC%9E%98%EB%AA%BB%EB%90%9C%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A0%95%ED%95%98%EA%B8%B0_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 수집된 데이터에서 누락된 값이나 잘못된 값 다루기

# %%
import gdown
gdown.download('https://bit.ly/3GisL6J', 'ns_book4.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3GisL6J
# To: /content/ns_book4.csv
# 100%|██████████| 55.5M/55.5M [00:00<00:00, 231MB/s]
# 'ns_book4.csv'

# %% [markdown]
# 판다스 --> 누락된 값: NaN
#
# NaN을 채우는 여러가지 방법 소개

# %%
import pandas as pd

ns_book4 = pd.read_csv('ns_book4.csv', low_memory=False)
ns_book4.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1   0.0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1   0.0  2021-03-19

# %% [markdown]
# 다섯행 NaN 표시된 열
# --> info() 메서드 사용: 열마다 NaN이 아닌 값이 몇개나 있는지 확인

# %%
ns_book4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384591 entries, 0 to 384590
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   번호       384591 non-null  int64
#  1   도서명      384188 non-null  object
#  2   저자       384393 non-null  object
#  3   출판사      379950 non-null  object
#  4   발행년도     384577 non-null  object
#  5   ISBN     384591 non-null  object
#  6   세트 ISBN  56576 non-null   object
#  7   부가기호     310386 non-null  object
#  8   권        63378 non-null   object
#  9   주제분류번호   364727 non-null  object
#  10  도서권수     384591 non-null  int64
#  11  대출건수     384591 non-null  float64
#  12  등록일자     384591 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 38.1+ MB

# %% [markdown]
# info() 메서드
# --> 원소 개수와 열 데이터 타입 기반 메모리 사용량 추정
#
# **정확한 메모리 사용량을 얻으려면 memory_usage매개변수에 'deep'옵션을 지정**

# %%
ns_book4.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384591 entries, 0 to 384590
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   번호       384591 non-null  int64
#  1   도서명      384188 non-null  object
#  2   저자       384393 non-null  object
#  3   출판사      379950 non-null  object
#  4   발행년도     384577 non-null  object
#  5   ISBN     384591 non-null  object
#  6   세트 ISBN  56576 non-null   object
#  7   부가기호     310386 non-null  object
#  8   권        63378 non-null   object
#  9   주제분류번호   364727 non-null  object
#  10  도서권수     384591 non-null  int64
#  11  대출건수     384591 non-null  float64
#  12  등록일자     384591 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 234.0 MB

# %% [markdown]
# ns_book4 --> 메모리 사용량 200MB 넘음

# %% [markdown]
# ##누락된 값 처리하기

# %% [markdown]
# **누락된 값을 표시하는 방법을 알아보고, 누락된 값을 다른 값으로 바꾸어 보자.**

# %% [markdown]
#  NaN을 직접 카운트할 수 있는 isna()메서드를 사용하면 편리
#
#   isna()메서드는 각 행이 비어 있는지를 나타내는 불리언 배열을 반환
#   그리고 sum()메서드를 이어서 호출하면 불리언 배열의 True개수로 비어 있는 행 개수를 얻을 수 있음

# %%
ns_book4.isna().sum()
# Out:
# 번호              0
# 도서명           403
# 저자            198
# 출판사          4641
# 발행년도           14
# ISBN            0
# 세트 ISBN    328015
# 부가기호        74205
# 권          321213
# 주제분류번호      19864
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64

# %% [markdown]
# isna()메서드와 반대로 누락되지 않은 값을 확인할 때는 notna()메서드를 사용

# %% [markdown]
# ns_book4데이터프레임의 '도서권수'열에 있는 첫 번째 행 값을 None으로 바꾼 후'도서권수'열에 isna()메서드를 적용해 누락된 값 세기

# %%
ns_book4.loc[0, '도서권수'] = None
ns_book4['도서권수'].isna().sum()
# Out:
# np.int64(1)

# %% [markdown]
# head()메서드로 처음 두 개의 행을 출력하여 첫 번째 행의 '도서권수' 값이 어떻게 바뀌었는지 확인

# %%
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN   NaN   0.0  2021-03-19
# 1    NaN   1.0   0.0  2021-03-19

# %% [markdown]
# NaN이 출력
#
# 그런데 두 번째 행의 '도서권수'값이 1이었는데 1.0으로 바뀌었다. 이는 판다스가 NaN을 특별한 실수 값으로 저장하기 때문
#
# 그래서 원래 데이터타입이 int64였던 '도서권수'열이 NaN을 표시하기 위해 float64로 자동 변환!

# %% [markdown]
# '도서권수'열의 첫번째 행을 원래대로 1로 바꿈
#
# 현재 데이터 타입이 실수형이므로 다시 정수형으로 바꾸어야 함
#
# 이때 '도서권수'열과 함께 '대출건수'열도 데이터타입을 int64로 바꿈
#
#  데이터타입을 지정할 때는 astype()메서드를 사용한다.** 매개변수를 {열 이름:데이터 타입}형식의 딕셔너리로 전달!**

# %%
ns_book4.loc[0, '도서권수'] = 1
ns_book4 = ns_book4.astype({'도서권수':'int32', '대출건수': 'int32'})
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %% [markdown]
# 정수형이 아니라 문자열을 저장할 수 있는 열에 None을 입력하면? 데이터 타입이 object인 '부가기호'열의 첫 번째 행에 None을 입력

# %%
ns_book4.loc[0, '부가기호'] = None
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN  부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  None  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN   NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %% [markdown]
# 정수형 열에 입력했을 때처럼 NaN으로 표시되지 않고 문자열 그대로 None으로 표시
#
#  그럼 None대신에 NaN을 입력?

# %% [markdown]
# 판다스는 NaN이라는 값을 따로 가지고 있지 않음
#
# 대신 넘파이 패키지에 있는 np.nan을 사용
#
# 따라서 첫 번째 행의 '부가기호'열의 값을 None에서 NaN으로 표시하려면 다음과 같이np.nan을 사용

# %%
import numpy as np

ns_book4.loc[0, '부가기호'] = np.nan
ns_book4.head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319     NaN  NaN  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969     NaN  NaN  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %% [markdown]
# ##누락된 값 바꾸기(1):loc,fillna()메서드
#
# ---

# %% [markdown]
# '세트ISBN'열은 대부분의 값이 비어 있음. 이누락된 값을 NaN이 아니라 빈 문자열('')로 바꿈

# %% [markdown]
# isna()메서드로 '세트ISBN'열의 NaN을 가리키는 set_isbn_na_rows 불리언 배열을 만들고, loc메서드에 전달

# %%
set_isbn_na_rows = ns_book4['세트 ISBN'].isna()
ns_book4.loc[set_isbn_na_rows, '세트 ISBN'] = ''

ns_book4['세트 ISBN'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# '세트ISBN'열의 NaN을 모두 빈 문자열로 바꾸었기 때문에 누락된 행의 개수는 0

# %% [markdown]
# 이처럼loc메서드로 NaN을 다른 값으로 바꿀 수 있지만, 조금 더 편리한 방법은 fillna()메서드
#
#  fillna()메서드에 원하는 값을 전달하면 NaN을 대체가능

# %% [markdown]
# ns_book4에 있는 모든 NaN을 '없음'문자열로 바꿈
#
#  fillna()메서드는 기본적으로 새로운 데이터프레임을 반환하므로 fillna()메서드에 이어서 isna()메서드를 연결하면 NaN의 개수를 셀 수 있음

# %%
ns_book4.fillna('없음').isna().sum()
# Out:
# 번호         0
# 도서명        0
# 저자         0
# 출판사        0
# 발행년도       0
# ISBN       0
# 세트 ISBN    0
# 부가기호       0
# 권          0
# 주제분류번호     0
# 도서권수       0
# 대출건수       0
# 등록일자       0
# dtype: int64

# %% [markdown]
# NaN이 모두 '없음'문자열로 바뀌어 NaN개수를 세면 0이 출력
#
# 특정 열만 선택해서 NaN을 바꿀 수도 있습니다.

# %%
ns_book4['부가기호'].fillna('없음').isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 하지만 특정 열을 선택한 후 fillna()메서드를 적용하면 앞의 실행 결과처럼 열 이름 없이 개수만 있는 판다스 시리즈 객체로 반환

# %% [markdown]
# '부가기호'열의 NaN을 바꾸면서 전체 데이터프레임을 반환하려면 다음처럼 열 이름과 바꾸려는 값으로 이루어진 딕셔너리를 전달하면 됨

# %%
ns_book4.fillna({'부가기호':'없음'}).isna().sum()
# Out:
# 번호              0
# 도서명           403
# 저자            198
# 출판사          4641
# 발행년도           14
# ISBN            0
# 세트 ISBN         0
# 부가기호            0
# 권          321213
# 주제분류번호      19864
# 도서권수            0
# 대출건수            0
# 등록일자            0
# dtype: int64

# %% [markdown]
# ##누락된 값 바꾸기(2):replace()메서드
#
# ---

# %% [markdown]
# replace()메서드는 NaN은 물론 어떤 값도 바꿀 수 있는 편리한 메서드

# %% [markdown]
# 바꾸려는 값이 하나라면 replace()메서드의 첫 번째 매개변수에는 원래 값을, 두 번째 매개변수에는새로운 값을 전달
# replace(원래 값, 새로운 값)

# %%
ns_book4.replace(np.nan, '없음').isna().sum()
# Out:
# 번호         0
# 도서명        0
# 저자         0
# 출판사        0
# 발행년도       0
# ISBN       0
# 세트 ISBN    0
# 부가기호       0
# 권          0
# 주제분류번호     0
# 도서권수       0
# 대출건수       0
# 등록일자       0
# dtype: int64

# %% [markdown]
# ##둘째, 바꾸려는 값이 여러 개일 때

# %% [markdown]
# 바꾸려는 값이 여러 개일 때는 리스트 형식으로 전달
# replace([원래 값1,원래 값2],[새로운 값1, 새로운 값2])

# %% [markdown]
# NaN을 '없음'으로 바꾸고 '2021'문자열을 '21'로 바꾸면

# %%
ns_book4.replace([np.nan, '2021'], ['없음', '21']).head(2)
# Out:
#    번호           도서명      저자   출판사 발행년도           ISBN 세트 ISBN 부가기호   권 주제분류번호  \
# 0   1       인공지능과 흙  김동훈 지음   민음사   21  9788937444319           없음  없음     없음
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무   21  9791190123969           없음  없음     없음
#
#    도서권수  대출건수        등록일자
# 0     1     0  2021-03-19
# 1     1     0  2021-03-19

# %% [markdown]
# 또는 리스트 대신({원래 값1:새로운 값1, 원래 값2:새로운 값2})처럼 딕셔너리 형식으로도 전달가능

# %%
ns_book4.replace({np.nan: '없음', '2021': '21'}).head(2)
# Out:
#    번호           도서명      저자   출판사 발행년도           ISBN 세트 ISBN 부가기호   권 주제분류번호  \
# 0   1       인공지능과 흙  김동훈 지음   민음사   21  9788937444319           없음  없음     없음
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무   21  9791190123969           없음  없음     없음
#
#    도서권수  대출건수        등록일자
# 0     1     0  2021-03-19
# 1     1     0  2021-03-19

# %% [markdown]
# ##셋째, 열 마다 다른 값으로 바꿀 때

# %% [markdown]
# 열 이름과 바꾸려는 값을 딕셔너리 형식으로 전달하여 열마다 다른 값을 바꿀 수 있음

# %% [markdown]
# replace({열 이름: 원래 값},새로운 값)

# %%
ns_book4.replace({'부가기호': np.nan}, '없음').head(2)
# Out:
#    번호           도서명      저자   출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사  2021  9788937444319           없음  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무  2021  9791190123969           없음  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %% [markdown]
# 또는 열 이름과 변경 전후의 값을 ({열 이름:{원래 값1:새로운 값1}})과 같이 중첩된 딕셔너리로 전달가능
#
#  '부가기호'열의 NaN을 '없음'으로 바꾸고 '발행년도'열의'2021'을 '21'로 바꾸면

# %%
ns_book4.replace({'부가기호': {np.nan: '없음'}, '발행년도': {'2021': '21'}}).head(2)
# Out:
#    번호           도서명      저자   출판사 발행년도           ISBN 세트 ISBN 부가기호    권  \
# 0   1       인공지능과 흙  김동훈 지음   민음사   21  9788937444319           없음  NaN
# 1   2  가짜 행복 권하는 사회  김태형 지음  갈매나무   21  9791190123969           없음  NaN
#
#   주제분류번호  도서권수  대출건수        등록일자
# 0    NaN     1     0  2021-03-19
# 1    NaN     1     0  2021-03-19

# %% [markdown]
# ## 정규 표현식

# %% [markdown]
# 정규표현식 또는 줄여서 정규식은 문자열 패턴을 찾아서 대체하기 위한 규칙의 모임
#
#  replace()메서드로 인덱스 100번과 101번 행의 네 자리 연구('2021')를 주 자리('21')로 바꾸어 보면

# %% [markdown]
# 이때 연도가 다르면 문제
#
#  연도가 '2021'일 경우 '21'로 바뀌지만 '2018'은 적용이 되지 않음

# %%
ns_book4.replace({'발행년도': {'2021': '21'}})[100:102]
# Out:
#       번호                                        도서명  \
# 100  101                  No라고 말할 줄 아는 남편과 아내 - 개정판
# 101  102  D2C 레볼루션 - 스타트업부터 글로벌 기업까지, 마켓 체인저의 필수 전략
#
#                                    저자   출판사  발행년도           ISBN 세트 ISBN 부가기호  \
# 100  헨리 클라우드, 존 타운센드 (지은이), 김진웅 (옮긴이)  좋은씨앗  2018  9788958743019          NaN
# 101        로런스 인그래시아 (지은이), 안기순 (옮긴이)    부키    21  9788960518483          NaN
#
#        권 주제분류번호  도서권수  대출건수        등록일자
# 100  NaN  234.9     1     1  2021-03-15
# 101  NaN  325.1     1     0  2021-03-15

# %% [markdown]
# 물론 replace()메서드에 '2018'을 '18'로 바꾸도록 추가할 수 있음
#
#  하지만 도서 발행 연도는 범위가 넓기 때문에 이런 식으로 일일이 모두 기재하여 바꾸는 것은 번거롭
#
#   이럴 때 정규 표현식을 사용하면 훨씬 간편하게 이런 작업을 수행가능

# %%
ns_book4.replace({'발행년도': {r'(\d\d)(\d\d)': r'\2'}}, regex=True)[100:102]
# Out:
#       번호                                        도서명  \
# 100  101                  No라고 말할 줄 아는 남편과 아내 - 개정판
# 101  102  D2C 레볼루션 - 스타트업부터 글로벌 기업까지, 마켓 체인저의 필수 전략
#
#                                    저자   출판사 발행년도           ISBN 세트 ISBN 부가기호  \
# 100  헨리 클라우드, 존 타운센드 (지은이), 김진웅 (옮긴이)  좋은씨앗   18  9788958743019          NaN
# 101        로런스 인그래시아 (지은이), 안기순 (옮긴이)    부키   21  9788960518483          NaN
#
#        권 주제분류번호  도서권수  대출건수        등록일자
# 100  NaN  234.9     1     1  2021-03-15
# 101  NaN  325.1     1     0  2021-03-15

# %% [markdown]
# 이때 정규 표현식 앞에 붙인 r문자는 원시문자열raw string을 만듬

# %%
ns_book4.replace({'발행년도': {r'(\d{2})(\d{2})': r'\1'}}, regex=True)[100:102]
# Out:
#       번호                                        도서명  \
# 100  101                  No라고 말할 줄 아는 남편과 아내 - 개정판
# 101  102  D2C 레볼루션 - 스타트업부터 글로벌 기업까지, 마켓 체인저의 필수 전략
#
#                                    저자   출판사 발행년도           ISBN 세트 ISBN 부가기호  \
# 100  헨리 클라우드, 존 타운센드 (지은이), 김진웅 (옮긴이)  좋은씨앗   20  9788958743019          NaN
# 101        로런스 인그래시아 (지은이), 안기순 (옮긴이)    부키   20  9788960518483          NaN
#
#        권 주제분류번호  도서권수  대출건수        등록일자
# 100  NaN  234.9     1     1  2021-03-15
# 101  NaN  325.1     1     0  2021-03-15

# %%
ns_book4.replace({'저자': {r'(.*)\s\(지은이\)(.*)\s\(옮긴이\)': r'\1\2'},
                  '발행년도': {r'\d{2}(\d{2})': r'\1'}}, regex=True)[100:102]
# Out:
#       번호                                        도서명                    저자  \
# 100  101                  No라고 말할 줄 아는 남편과 아내 - 개정판  헨리 클라우드, 존 타운센드, 김진웅
# 101  102  D2C 레볼루션 - 스타트업부터 글로벌 기업까지, 마켓 체인저의 필수 전략        로런스 인그래시아, 안기순
#
#       출판사 발행년도           ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 100  좋은씨앗   18  9788958743019          NaN  NaN  234.9     1     1  2021-03-15
# 101    부키   21  9788960518483          NaN  NaN  325.1     1     0  2021-03-15

# %% [markdown]
# ## 잘못된 값 바꾸기

# %%
# 아래 코드는 오류 발생
ns_book4.astype({'발행년도': 'int32'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_547/4031283106.py in <cell line: 0>()
#       1 # 아래 코드는 오류 발생
# ----> 2 ns_book4.astype({'발행년도': 'int32'})
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6618                 else:
#    6619                     try:
# -> 6620                         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621                     except ValueError as ex:
#    6622                         ex.args = (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '1988.': Error while type casting for column '발행년도'

# %% [markdown]
# '1988'이라는 연도를 변환할 수 없어 오류가 발생
#
#  아무래도 숫자가 아닌 다른 문자가 들어있음

# %% [markdown]
# 판다스 시리즈 객체는 str속성 아래 다양한 문자열 처리 함수를 제공
#
#  그중contain()메서드는 시리즈나 인덱스에서 문자열 패턴을 포함하고 있는지 검사
#
#   '발행년도'열에 '1988'이 포함된 행의 개수를 세어 보기

# %%
ns_book4['발행년도'].str.contains('1988').sum()
# Out:
# 407

# %%
invalid_number = ns_book4['발행년도'].str.contains('\D', na=True)
print(invalid_number.sum())
ns_book4[invalid_number].head()
# Out:
# 1777
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_547/1631807378.py:1: SyntaxWarning: invalid escape sequence '\D'
#   invalid_number = ns_book4['발행년도'].str.contains('\D', na=True)
#           번호                       도서명  \
# 19138  19565                      단국강토
# 19227  19736                    삼성의 역사
# 26097  26812                  배고픈 애벌레
# 29817  30586  (The) Sopranos sessions
# 29940  30709                    다음엔 너야
#
#                                                       저자                 출판사  \
# 19138                                              홍태수 저             매일경제신문사
# 19227                                              송부웅 撰                  삼양
# 26097                                  에릭 칼 글·그림 ;이희재 옮김               더큰컴퍼니
# 29817  Matt Zoller Seitz,$eAlan Sepinwall,$eLaura Lip...  Harry N Abrams Inc
# 29940                         에른스트 얀들 글;노르만 융에 그림;박상순 옮김                 비룡소
#
#                발행년도           ISBN        세트 ISBN 부가기호    권  주제분류번호  도서권수  \
# 19138         1988.  9788974420031                 NaN  NaN   511.1     1
# 19227  단기4334[2001]  9788985464369                   0  NaN  911.02     1
# 26097        [2019]  9788959514083                 NaN  NaN     843     1
# 29817         2019.  9781419734946                 NaN  NaN  326.76     1
# 29940         2018.  9788949110646  9788949110004    7  NaN     853     1
#
#        대출건수        등록일자
# 19138     1  2019-12-19
# 19227     1  2019-12-06
# 26097     0  2019-08-12
# 29817     0  2019-06-13
# 29940     9  2019-06-04

# %%
ns_book5 = ns_book4.replace({'발행년도':r'.*(\d{4}).*'}, r'\1', regex=True)
ns_book5[invalid_number].head()
# Out:
#           번호                       도서명  \
# 19138  19565                      단국강토
# 19227  19736                    삼성의 역사
# 26097  26812                  배고픈 애벌레
# 29817  30586  (The) Sopranos sessions
# 29940  30709                    다음엔 너야
#
#                                                       저자                 출판사  \
# 19138                                              홍태수 저             매일경제신문사
# 19227                                              송부웅 撰                  삼양
# 26097                                  에릭 칼 글·그림 ;이희재 옮김               더큰컴퍼니
# 29817  Matt Zoller Seitz,$eAlan Sepinwall,$eLaura Lip...  Harry N Abrams Inc
# 29940                         에른스트 얀들 글;노르만 융에 그림;박상순 옮김                 비룡소
#
#        발행년도           ISBN        세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 19138  1988  9788974420031                 NaN  NaN   511.1     1     1
# 19227  2001  9788985464369                   0  NaN  911.02     1     1
# 26097  2019  9788959514083                 NaN  NaN     843     1     0
# 29817  2019  9781419734946                 NaN  NaN  326.76     1     0
# 29940  2018  9788949110646  9788949110004    7  NaN     853     1     9
#
#              등록일자
# 19138  2019-12-19
# 19227  2019-12-06
# 26097  2019-08-12
# 29817  2019-06-13
# 29940  2019-06-04

# %%
unkown_year = ns_book5['발행년도'].str.contains('\D', na=True)
print(unkown_year.sum())
ns_book5[unkown_year].head()
# Out:
# 67
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_547/2094730826.py:1: SyntaxWarning: invalid escape sequence '\D'
#   unkown_year = ns_book5['발행년도'].str.contains('\D', na=True)
#             번호                도서명        저자      출판사     발행년도           ISBN  \
# 30838    31616       본격 한중일 세계사 5  굽시니스트 지음   위즈덤하우스      NaN  9791190065092
# 39130    40141     정책금융의 현황과 발전과제   정책금융연구회   한국산업은행      NaN  9788992784108
# 39256    40268  서울지역 유적 발굴조사 총서 3   서울역사박물관  서울역사박물관      NaN  9791186324714
# 76836    81202            흰머리 큰줄기    한호진 지음    秀文出版社  [발행년불명]  9788973010769
# 150543  160436          (속) 경제학사     박장환 지음      NaN   [20--]  9788994339207
#
#               세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 30838                  NaN  NaN    NaN     0     0  2019-05-28
# 39130                  NaN  NaN  327.1     1     0  2019-01-22
# 39256   9791186324431  NaN  NaN    NaN     0     0  2019-01-22
# 76836                    0  NaN  699.1     1     1  2016-11-10
# 150543                   1  NaN  320.9     1     2  2012-11-19

# %% [markdown]
# 1,777개에서 67개로 줄음! 이제 변환되지 않은 값은 NaN이거나 네 자리 숫자가 아닌 값.
#
#  이런 값은 어떻게 변환할지 알 수 없기 때문에 임의로 -1값으로 바꾼다음 astype()메서드로 '발행년도'열의 데이터 타입을 정수형인 int64로변환

# %%
ns_book5.loc[unkown_year, '발행년도'] = '-1'
ns_book5 = ns_book5.astype({'발행년도': 'int32'})

# %% [markdown]
#  연도 중에 이상하게 아주 큰 값이나 작은 값이 들어 있는 경우가 있음
#
#  먼저 연도가 4000년이 넘는 경우를 확인

# %% [markdown]
# gt()메서드는 전달된 값보다 큰 값을 찾음. 연도가 4000년이 넘는 행의 전체 개수를 확인하기 위해 sum()함수를 함께 사용

# %%
ns_book5['발행년도'].gt(4000).sum()
# Out:
# np.int64(131)

# %% [markdown]
# 4000년이 넘는 경우가 131권
#
#  아마도 단군기원을 사용한 것 같음

# %%
dangun_yy_rows = ns_book5['발행년도'].gt(4000)
ns_book5.loc[dangun_yy_rows, '발행년도'] = ns_book5.loc[dangun_yy_rows, '발행년도'] - 2333

# %%
dangun_year = ns_book5['발행년도'].gt(4000)
print(dangun_year.sum())
ns_book5[dangun_year].head(2)
# Out:
# 13
#             번호                                         도서명               저자  \
# 222858  234268                                  Modern art  [computer file]
# 270269  282852  현대 영어학=Linguistic theory in modern english              이재영
#
#             출판사  발행년도           ISBN 세트 ISBN 부가기호    권   주제분류번호  도서권수  대출건수  \
# 222858  GROLIER  7611  9780717233243          NaN  NaN  609.205     1     1
# 270269     열림기획  7634  9788986705072            1  NaN    740.1     1     6
#
#               등록일자
# 222858  2009-05-07
# 270269  2007-04-14

# %% [markdown]
# 연도가 이상하게 높은 도서가 13권이
#
# 이런 도서는 모두 -1로 표사

# %%
ns_book5.loc[dangun_year, '발행년도'] = -1

# %% [markdown]
# 마지막으로 연독 ㅏ작은 값도 확인
#
#  이번에는 0보다 크고 1900년도 이전의 도서

# %%
old_books = ns_book5['발행년도'].gt(0) & ns_book5['발행년도'].lt(1900)
ns_book5[old_books]
# Out:
#             번호                                           도서명  \
# 61149    64093         고흐 씨, 시 읽어 줄까요 :내 마음을 알아주는 시와 그림의 만남
# 70566    74347                                  정신 병리학의 문제들
# 79550    84164  (최근 7년간) 중요 민법판례 :[2009년 1월~2016년 6월 중요 판례]
# 147950  157759              (한·중·일) 밥상 문화 :대표음식으로 본 3국 문화비교
# 194576  205407                                책으로 뒤덮인 집의 비밀
# 287252  300283                                     (밝혀질)우리歷史
#
#                                    저자      출판사  발행년도           ISBN  \
# 61149                          이운진 지음      사계절   176  9788958284277
# 70566        지은이: 지그문트 프로이트 ;옮긴이: 황보석     열린책들   151  9788932905181
# 79550                          이광섭 편저      법학사   163  9788962898651
# 147950                         김경은 지음      이가서   132  9788958643012
# 194576  N.E. 보드 지음 ;피터 퍼거슨 그림 ;김지현 옮김     개암나무  1015  9788992844413
# 287252                          吳在城 著  黎民族史硏究會  1607  9788986892130
#
#               세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수        등록일자
# 61149                    0  NaN   811.7     1     6  2017-10-27
# 70566   9788932905082    9   10   185.5     1     4  2017-04-26
# 79550                    9  NaN     365     1    14  2016-09-27
# 147950                   0  NaN  381.75     1    30  2013-02-19
# 194576                   7  NaN     843     1    15  2010-08-18
# 287252                   0  NaN     911     1     5  2006-07-06

# %% [markdown]
# 여전히 잘못된 값
#
# 이도서도 연도를 -1로 설정하고 전체 행 개수를 확인

# %%
ns_book5.loc[old_books, '발행년도'] = -1

# %%
ns_book5['발행년도'].eq(-1).sum()
# Out:
# np.int64(86)

# %% [markdown]
# ## 누락된 정보 채우기

# %% [markdown]
# 혼공분석은 남산 도서관 대출 데이터에서 '도서명','저자','출판사','발행년도'열이 분석에 중요하다고 판단
#
#  따라서 이 4개 열에는 누락된 값이 있으면 안됨
#
#  먼저 '도서명','저자','출판사'열에 누락된 값이 있거나 '발행년도'열이 -1인 행의 개수를 확인

# %%
na_rows = ns_book5['도서명'].isna() | ns_book5['저자'].isna() \
          | ns_book5['출판사'].isna() | ns_book5['발행년도'].eq(-1)
print(na_rows.sum())
ns_book5[na_rows].head(2)
# Out:
# 5268
#       번호          도서명          저자  출판사  발행년도           ISBN 세트 ISBN 부가기호    권  \
# 78    79   아산 정주영 레거시         김화진  NaN  2021  9788952129529          NaN  NaN
# 265  278  골목의 시간을 그리다  정명섭.김효찬 지음  NaN  2021  9791191266054          NaN  NaN
#
#     주제분류번호  도서권수  대출건수        등록일자
# 78     325     1     1  2021-03-15
# 265    NaN     1     0  2021-03-12

# %% [markdown]
# 값이 누락되었거나 알 수 없는 행이 5262개. 뷰티플수프를 사용해 이런 값을 채워 보겠음.
#
# 먼저 requests패키지와 bs4패키지를 임포트

# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_book_title(isbn):
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옵니다.
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    # 클래스 이름이 'gd_name'인 a 태그의 텍스트를 가져옴
    title = soup.find('a', attrs={'class':'gd_name'}) \
            .get_text()
    return title

# %% [markdown]
# 작성한 get_book_title()함수 책의 ISBN으로 테스트

# %%
get_book_title(9791191266054)
# Out:
# '골목의 시간을 그리다'

# %%
import re

def get_book_info(row):
    title = row['도서명']
    author = row['저자']
    pub = row['출판사']
    year = row['발행년도']
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옴
    r = requests.get(url.format(row['ISBN']))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    try:
        if pd.isna(title):
            # 클래스 이름이 'gd_name'인 a 태그의 텍스트를 가져옴
            title = soup.find('a', attrs={'class':'gd_name'}) \
                    .get_text()
    except AttributeError:
        pass

    try:
        if pd.isna(author):
            # 클래스 이름이 'info_auth'인 span 태그 아래 a 태그의 텍스트를 가져옴
            authors = soup.find('span', attrs={'class':'info_auth'}) \
                          .find_all('a')
            author_list = [auth.get_text() for auth in authors]
            author = ','.join(author_list)
    except AttributeError:
        pass

    try:
        if pd.isna(pub):
            # 클래스 이름이 'info_auth'인 span 태그 아래 a 태그의 텍스트를 가져옵니다.
            pub = soup.find('span', attrs={'class':'info_pub'}) \
                      .find('a') \
                      .get_text()
    except AttributeError:
        pass

    try:
        if year == -1:
            # 클래스 이름이 'info_date'인 span 태그 아래 텍스트를 가져옴
            year_str = soup.find('span', attrs={'class':'info_date'}) \
                           .get_text()
            # 정규식으로 찾은 값 중에 첫 번째 것만 사용함
            year = re.findall(r'\d{4}', year_str)[0]
    except AttributeError:
        pass

    return title, author, pub, year

# %%
updated_sample = ns_book5[na_rows].head(2).apply(get_book_info,
    axis=1, result_type ='expand')
updated_sample
# Out:
#                0           1           2     3
# 78    아산 정주영 레거시         김화진  서울대학교출판문화원  2021
# 265  골목의 시간을 그리다  정명섭.김효찬 지음      초록비책공방  2021

# %%
gdown.download('http://bit.ly/3UJZiHw', 'ns_book5_update.csv', quiet=False)

ns_book5_update = pd.read_csv('ns_book5_update.csv', index_col=0)
ns_book5_update.head()
# Out:
# Downloading...
# From: http://bit.ly/3UJZiHw
# To: /content/ns_book5_update.csv
# 100%|██████████| 406k/406k [00:00<00:00, 93.0MB/s]
#                           도서명               저자         출판사  발행년도
# 78                 아산 정주영 레거시              김화진  서울대학교출판문화원  2021
# 265               골목의 시간을 그리다       정명섭.김효찬 지음      초록비책공방  2021
# 354                    한국인의 맛           정명섭 지음         추수밭  2021
# 539              한성부, 달 밝은 밤에           김이삭 지음      고즈넉이엔티  2021
# 607  100일 완성 마그마 러시아어 중고급 단어장  러포자 구제 연구소 외 지음         문예림  2021

# %%
ns_book5.update(ns_book5_update)

na_rows = ns_book5['도서명'].isna() | ns_book5['저자'].isna() \
          | ns_book5['출판사'].isna() | ns_book5['발행년도'].eq(-1)
print(na_rows.sum())
# Out:
# 4615
# /tmp/ipykernel_547/1890996919.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[2021 2021 2021 ... 1996 1996 1995]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   ns_book5.update(ns_book5_update)

# %%
ns_book5 = ns_book5.astype({'발행년도': 'int32'})

# %%
ns_book6 = ns_book5.dropna(subset=['도서명','저자','출판사'])
ns_book6 = ns_book6[ns_book6['발행년도'] != -1]
ns_book6.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0          NaN  NaN    NaN     1     0  2021-03-19
# 1          NaN  NaN    NaN     1     0  2021-03-19
# 2          NaN  NaN    NaN     1     0  2021-03-19
# 3          NaN  NaN    NaN     1     0  2021-03-19
# 4          NaN  NaN    NaN     1     0  2021-03-19

# %%
ns_book6.to_csv('ns_book6.csv', index=False)

# %%
def data_fixing(ns_book4):
    """
    잘못된 값을 수정하거나 NaN 값을 채우는 함수

    :param ns_book4: data_cleaning() 함수에서 전처리된 데이터프레임
    """
    # 도서권수와 대출건수를 int32로 바꿉니다.
    ns_book4 = ns_book4.astype({'도서권수':'int32', '대출건수': 'int32'})
    # NaN인 세트 ISBN을 빈문자열로 바꿉니다.
    set_isbn_na_rows = ns_book4['세트 ISBN'].isna()
    ns_book4.loc[set_isbn_na_rows, '세트 ISBN'] = ''

    # 발행년도 열에서 연도 네 자리를 추출하여 대체합니다. 나머지 발행년도는 -1로 바꿉니다.
    ns_book5 = ns_book4.replace({'발행년도':'.*(\d{4}).*'}, r'\1', regex=True)
    unkown_year = ns_book5['발행년도'].str.contains('\D', na=True)
    ns_book5.loc[unkown_year, '발행년도'] = '-1'

    # 발행년도를 int32로 바꿉니다.
    ns_book5 = ns_book5.astype({'발행년도': 'int32'})
    # 4000년 이상인 경우 2333년을 뺍니다.
    dangun_yy_rows = ns_book5['발행년도'].gt(4000)
    ns_book5.loc[dangun_yy_rows, '발행년도'] = ns_book5.loc[dangun_yy_rows, '발행년도'] - 2333
    # 여전히 4000년 이상인 경우 -1로 바꿉니다.
    dangun_year = ns_book5['발행년도'].gt(4000)
    ns_book5.loc[dangun_year, '발행년도'] = -1
    # 0~1900년 사이의 발행년도는 -1로 바꿉니다.
    old_books = ns_book5['발행년도'].gt(0) & ns_book5['발행년도'].lt(1900)
    ns_book5.loc[old_books, '발행년도'] = -1

    # 도서명, 저자, 출판사가 NaN이거나 발행년도가 -1인 행을 찾습니다.
    na_rows = ns_book5['도서명'].isna() | ns_book5['저자'].isna() \
              | ns_book5['출판사'].isna() | ns_book5['발행년도'].eq(-1)
    # 교보문고 도서 상세 페이지에서 누락된 정보를 채웁니다.
    updated_sample = ns_book5[na_rows].apply(get_book_info,
        axis=1, result_type ='expand')
    updated_sample.columns = ['도서명','저자','출판사','발행년도']
    ns_book5.update(updated_sample)

    # 도서명, 저자, 출판사가 NaN이거나 발행년도가 -1인 행을 삭제합니다.
    ns_book6 = ns_book5.dropna(subset=['도서명','저자','출판사'])
    ns_book6 = ns_book6[ns_book6['발행년도'] != -1]

    return ns_book6
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# <>:15: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# <>:15: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_547/3538836219.py:14: SyntaxWarning: invalid escape sequence '\d'
#   ns_book5 = ns_book4.replace({'발행년도':'.*(\d{4}).*'}, r'\1', regex=True)
# /tmp/ipykernel_547/3538836219.py:15: SyntaxWarning: invalid escape sequence '\D'
#   unkown_year = ns_book5['발행년도'].str.contains('\D', na=True)
